# %%
import pandas as pd

# %%
df = pd.read_csv("c:/Users/Admin/Downloads/traffic_stop.csv")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6244\513994954.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("c:/Users/Admin/Downloads/traffic_stop.csv")
#         stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0      2020-01-01   0:00:00       Canada             M              59
# 1      2020-01-01   0:01:00        India             M              35
# 2      2020-01-01   0:02:00          USA             M              26
# 3      2020-01-01   0:03:00       Canada             M              26
# 4      2020-01-01   0:04:00       Canada             M              62
# ...           ...       ...          ...           ...             ...
# 65533  2020-02-15  12:13:00        India             F              54
# 65534  2020-02-15  12:14:00       Canada             F              18
# 65535  2020-02-15  12:15:00          USA             M              27
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65538 entries, 0 to 65537
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           65538 non-null  object
#  1   stop_time           65538 non-null  object
#  2   country_name        65538 non-null  object
#  3   driver_gender       65538 non-null  object
#  4   driver_age_raw      65538 non-null  int64
#  5   driver_age          65538 non-null  int64
#  6   driver_race         65538 non-null  object
#  7   violation_raw       65538 non-null  object
#  8   violation           65538 non-null  object
#  9   search_conducted    65538 non-null  bool
#  10  search_type         43818 non-null  object
#  11  stop_outcome        65538 non-null  object
#  12  is_arrested         65538 non-null  bool
#  13  stop_duration       65538 non-null  object
#  14  drugs_related_stop  65538 non-null  bool
# ...

# %%
df["search_type"] = df["search_type"].fillna("Unknown")
df
# Out:
#         stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0      2020-01-01   0:00:00       Canada             M              59
# 1      2020-01-01   0:01:00        India             M              35
# 2      2020-01-01   0:02:00          USA             M              26
# 3      2020-01-01   0:03:00       Canada             M              26
# 4      2020-01-01   0:04:00       Canada             M              62
# ...           ...       ...          ...           ...             ...
# 65533  2020-02-15  12:13:00        India             F              54
# 65534  2020-02-15  12:14:00       Canada             F              18
# 65535  2020-02-15  12:15:00          USA             M              27
# 65536  2020-02-15  12:16:00       Canada             F              49
# 65537  2020-02-15  12:17:00          USA             F              72
#
#        driver_age driver_race     violation_raw violation  search_conducted  \
# ...

# %%
df["is_arrested"] = df["is_arrested"].astype(int)
df["search_conducted"] = df["search_conducted"].astype(int)
df["drugs_related_stop"] = df["drugs_related_stop"].astype(int)

# %%
df["stop_date"] = pd.to_datetime(df["stop_date"], errors='coerce')
df["stop_date"] = df["stop_date"].dt.strftime('%Y-%m-%d')

# %%
df.to_csv('cleaned_traffic_stops', index=False)

# %%
from sqlalchemy import create_engine

# Create SQLite DB in memory (or use 'sqlite:///traffic.db' for file)
engine = create_engine('sqlite:///traffic_stops.db')

# %%
import pandas as pd

# Load the cleaned dataset
df = pd.read_csv('C:/Users/Admin/Desktop/streamlit/streamlit/cleaned_traffic_stops.csv')
df
# Out:
#         stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0      2020-01-01   0:00:00       Canada             M              59
# 1      2020-01-01   0:01:00        India             M              35
# 2      2020-01-01   0:02:00          USA             M              26
# 3      2020-01-01   0:03:00       Canada             M              26
# 4      2020-01-01   0:04:00       Canada             M              62
# ...           ...       ...          ...           ...             ...
# 65533  2020-02-15  12:13:00        India             F              54
# 65534  2020-02-15  12:14:00       Canada             F              18
# 65535  2020-02-15  12:15:00          USA             M              27
# 65536  2020-02-15  12:16:00       Canada             F              49
# 65537  2020-02-15  12:17:00          USA             F              72
#
#        driver_age driver_race     violation_raw violation  search_conducted  \
# ...

# %%
from sqlalchemy import create_engine

username = 'root'
password = '123456'
host = '127.0.0.1'        
port = '3306'             
database = 'traffic_logs'

engine = create_engine(f'mysql+mysqlconnector://{username}:{password}@{host}:{port}/{database}')

# %%
CREATE TABLE traffic_stops (
    stop_date DATE NOT NULL,                         -- Date of stop
    stop_time TIME,                                  -- Time of stop
    country_name VARCHAR(100),                       -- Place of stop
    driver_gender VARCHAR(10),                       -- Drivers gender
    driver_age INT,                                  -- Cleaned age
    driver_race VARCHAR(50),                         -- Drivers race/ethnicity
    violation VARCHAR(100),                          -- Type of violation
    search_conducted BOOLEAN DEFAULT FALSE,          -- Was a search conducted?
    search_type VARCHAR(50),                         -- Type (Frisk, Vehicle, etc.)
    stop_outcome VARCHAR(50),                        -- Outcome (Warning, Arrest, etc.)
    is_arrested BOOLEAN DEFAULT FALSE,               -- Was the driver arrested?
    stop_duration VARCHAR(20),                       -- Duration (e.g., '5 Min')
    drugs_related_stop BOOLEAN DEFAULT FALSE,        -- Drug-related stop?
    vehicle_number VARCHAR(20),                      -- Vehicle identifier
);

# %%
LOAD DATA INFILE 'C:/ProgramData/MySQL/MySQL Server 8.0/Uploads/cleaned_traffic_stops.csv'
INTO TABLE traffic_stops
FIELDS TERMINATED BY ','
ENCLOSED BY '"'
LINES TERMINATED BY '\n'
IGNORE 1 ROWS
(
    stop_date,
    stop_time,
    country_name,
    driver_gender,
    @driver_age_raw,  -- skipped
    driver_age,
    driver_race,
    @violation_raw,   -- skipped
    violation,
    search_conducted,
    search_type,
    stop_outcome,
    is_arrested,
    stop_duration,
    drugs_related_stop,
    vehicle_number
);
